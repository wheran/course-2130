# %% [markdown]
# # Requests

# %%
import requests

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings. Basic GET
#     usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> 'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key2": "value2",
#            "key1": "value1"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <http://python-requests.org>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
response = requests.get('https://google.com/to/')
response.text
# Out:
# '<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 404 (Not Found)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-border-image:u
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.core.display import display, HTML

display(HTML(requests.get('https://google.com').text))
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ru"><head><meta content="&#1055;&#1086;&#1080;&#1089;&#1082; &#1080;&#1085;&#1092;&#1086;&#1088;&#1084;&#1072;&#1094;&#1080;&#1080; &#1074; &#1080;&#1085;&#1090;&#1077;&#1088;&#1085;&#1077;&#1090;&#1077;: &#1074;&#1077;&#1073; &#1089;&#1090;&#1088;&#1072;&#1085;&#1080;&#1094;&#1099;, &#1082;&#1072;&#1088;&#1090;&#1080;&#1085;&#1082;&#1080;, &#1074;&#1080;&#1076;&#1077;&#1086; &#1080; &#1084;&#1085;&#1086;&#1075;&#1086;&#1077; &#1076;&#1088;&#1091;&#1075;&#1086;&#1077;." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="g0lt4rm+yjg6N1LCJYiKYg==">(function(){window.google={kEI:'7eZ2X8vzDcyNwPAP4_WaqAw',kEXPI:'0,202160,2,1151585,5662,731,223,5105,206,3204,10,1226,364,1499,611,92,114,383,246,5,1354,648,3452,314,3,
# ...

# %% [markdown]
# # Regex
#
# https://docs.python.org/3/library/re.html
#
# https://regex101.com/  - удобен для тестирования
#
# ![image.png](attachment:image.png)
# https://tproger.ru/translations/regular-expression-python/

# %%
import re

# %%
re.sub(r'\.|;|:', '_', 'Hi.....I am;;;;:::robot:::;;;..')
# Out:
# 'Hi_____I am_______robot________'

# %%
re.findall(r'I am \d{1,3}', 'I am 24')
# Out:
# ['I am 24']

# %%
re.findall(r'I am (\d{1,3})', 'I am 24')
# Out:
# ['24']

# %%
re.findall(r'I am ([^0-1][0-9])', 'I am 21')
# Out:
# ['21']

# %%
pattern = re.compile(r'I am ([^0-1][0-9])')
list(filter(pattern.search, ['I am 11', 'I am 21']))
# Out:
# ['I am 21']

# %%
# find all phone numbers like `222-34-01`, `2223401`, `222  32  01adas` -> 2223401

# %%
test_str = 'my number is 222-34-01. my second number is 2223401. Please call me on 222  32  01adas'
re.findall(r'\d{3}-\d{2}-\d{2}|\d{7}|\d+\s+\d+\s+\d+', test_str)
# Out:
# ['222-34-01', '2223401', '222  32  01']

# %%
# find all phone numbers like `+1222-34-01`, `+1 2223401`, `-1222  32  01adas` -> 2223401

# %%
test_str = 'my number is +1222-34-01. my second number is 12223401. Please call me on 1222  32  01adas'
re.findall(r'(\+1|1)\s|(\d{3}-\d{2}-\d{2}|\d{7}|\d+\s+\d+\s+\d+)', test_str)
# Out:
# [('', '222-34-01'), ('', '1222340'), ('', '1222  32  01')]
